# %%
import skvideo
# skvideo.setFFmpegPath("/usr/bin")
import skvideo.io 


import matplotlib.pyplot as plt
from torchvision import transforms
from torch.autograd import Variable
import numpy as np
import torch.optim as optim
import PIL
import json 
import torchvision.models as models
import time
from TREMBA.FCN import *
from TREMBA.utils import *
from TREMBA.dataloader import *
import pandas as pd
import os
from pretrainedmodels import utils as ptm_utils
from pathlib import Path
from utils import * 

from video_caption_pytorch.models import EncoderRNN, DecoderRNN, S2VTAttModel, S2VTModel
from video_caption_pytorch.dataloader import VideoDataset
from video_caption_pytorch.process_features import process_batches
from video_caption_pytorch.process_features import create_batches as create_batches_eval
from video_caption_pytorch.models.ConvS2VT import ConvS2VT
from video_caption_pytorch.misc import utils as utils

# %%
from commence_attack_CW import *

# %%
config_path = "configs/attack_cw"
configs = os.listdir(config_path)
for c in range(len(configs)):
    
    print(f"Config {c}/{len(configs)}")
    cpath = configs[c]
        
    config_name = os.path.join(config_path, cpath)
    with open(config_name, 'r') as reader:
        config = json.load(reader)

    CWmain(config)
# Out:
# Config 0/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_77iDIp40m9E_159_181.avi_10_10_run_summary.csv, skipping
# Config 1/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_7HcYJKMxpcg_20_28.avi_10_10_run_summary.csv, skipping
# Config 2/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_AJJ-iQkbRNE_97_109.avi_10_10_run_summary.csv, skipping
# Config 3/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_kI6MWZrl8v8_149_161.avi_10_10_run_summary.csv, skipping
# Config 4/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_MSrJTeKNzdI_32_36.avi_10_10_run_summary.csv, skipping
# Config 5/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_nc8hwLaOyZU_1_19.avi_10_10_run_summary.csv, skipping
# Config 6/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_NKtfKR4GNjU_0_20.avi_10_10_run_summary.csv, skipping
# Config 7/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_O2qiPS2NCeY_2_18.avi_10_10_run_summary.csv, skipping
# Config 8/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_pFSoWsocv0g_8_17.avi_10_10_run_summary.csv, skipping
# Config 9/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_SaYwh6chmiw_15_40.avi_10_10_run_summary.csv, skipping
# Config 10/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_YEmS8ZQIhTA_7_20.avi_10_10_run_summary.csv, skipping
# Config 11/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_77iDIp40m9E_159_181.avi_30_10_run_summary.csv, skipping
# Config 12/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_7HcYJKMxpcg_20_28.avi_30_10_run_summary.csv, skipping
# Config 13/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_AJJ-iQkbRNE_97_109.avi_30_10_run_summary.csv, skipping
# Config 14/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_kI6MWZrl8v8_149_161.avi_30_10_run_summary.csv, skipping
# Config 15/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_MSrJTeKNzdI_32_36.avi_30_10_run_summary.csv, skipping
# Config 16/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_nc8hwLaOyZU_1_19.avi_30_10_run_summary.csv, skipping
# Config 17/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_NKtfKR4GNjU_0_20.avi_30_10_run_summary.csv, skipping
# Config 18/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_O2qiPS2NCeY_2_18.avi_30_10_run_summary.csv, skipping
# Config 19/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_pFSoWsocv0g_8_17.avi_30_10_run_summary.csv, skipping
# Config 20/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_SaYwh6chmiw_15_40.avi_30_10_run_summary.csv, skipping
# Config 21/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_YEmS8ZQIhTA_7_20.avi_30_10_run_summary.csv, skipping
# Config 22/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_77iDIp40m9E_159_181.avi_40_10_run_summary.csv, skipping
# Config 23/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_7HcYJKMxpcg_20_28.avi_40_10_run_summary.csv, skipping
# Config 24/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_AJJ-iQkbRNE_97_109.avi_40_10_run_summary.csv, skipping
# Config 25/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_kI6MWZrl8v8_149_161.avi_40_10_run_summary.csv, skipping
# Config 26/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_MSrJTeKNzdI_32_36.avi_40_10_run_summary.csv, skipping
# Config 27/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_nc8hwLaOyZU_1_19.avi_40_10_run_summary.csv, skipping
# Config 28/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_NKtfKR4GNjU_0_20.avi_40_10_run_summary.csv, skipping
# Config 29/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_O2qiPS2NCeY_2_18.avi_40_10_run_summary.csv, skipping
# Config 30/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_pFSoWsocv0g_8_17.avi_40_10_run_summary.csv, skipping
# Config 31/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_SaYwh6chmiw_15_40.avi_40_10_run_summary.csv, skipping
# Config 32/33
#
# Run already found at data/adversarial_videos_CW/vgg16_217_YEmS8ZQIhTA_7_20.avi_40_10_run_summary.csv, skipping
