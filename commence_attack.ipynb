# %%
import skvideo
# skvideo.setFFmpegPath("/usr/bin")
import skvideo.io 


import matplotlib.pyplot as plt
from torchvision import transforms
from torch.autograd import Variable
import numpy as np
import torch.optim as optim
import PIL
import json 
import torchvision.models as models
import time
from TREMBA.FCN import *
from TREMBA.utils import *
from TREMBA.dataloader import *
import pandas as pd
import os
from pretrainedmodels import utils as ptm_utils
from pathlib import Path
from utils import * 

from video_caption_pytorch.models import EncoderRNN, DecoderRNN, S2VTAttModel, S2VTModel
from video_caption_pytorch.dataloader import VideoDataset
from video_caption_pytorch.process_features import process_batches
from video_caption_pytorch.process_features import create_batches as create_batches_eval
from video_caption_pytorch.models.ConvS2VT import ConvS2VT
from video_caption_pytorch.misc import utils as utils

# %%
from commence_attack import *

# %%
config_path = "configs/attack"
configs = os.listdir(config_path)
for c in range(len(configs)):
    print(f"Config {c}/{len(configs)}")
    cpath = configs[c]
        
    config_name = os.path.join(config_path, cpath)
    with open(config_name, 'r') as reader:
        config = json.load(reader)
    
    main(config)
# Out:
# Config 0/33
# Loaded configs
# Total frames:  551
# Got model
# Generating 3 batches...
# c:\Users\suman\anaconda3\envs\p38\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Original classes:
#  516  516  516  516  516  516  51  51  719  516  465  516  516  465  516  465  51  861  708  708  708  465  465  465  51  532  51  516  516  516  516  516 Loaded generator
# Encoder, decoder loaded
# F function loaded
#
# -------------------------------
# Frame number:  0
# Starting attack
# 	Iteration 0 / 2501
# iteration: 0 loss: 5.332810401916504, l2_deviation 4.915459156036377
# 	Iteration 1 / 2501
# 	Iteration 2 / 2501
# 	Iteration 3 / 2501
# 	Iteration 4 / 2501
# 	Iteration 5 / 2501
# 	Iteration 6 / 2501
# 	Iteration 7 / 2501
# 	Iteration 8 / 2501
# 	Iteration 9 / 2501
# 	Iteration 10 / 2501
# 	Iteration 11 / 2501
# 	Iteration 12 / 2501
# 	Iteration 13 / 2501
# 	Iteration 14 / 2501
# 	Iteration 15 / 2501
# 	Iteration 16 / 2501
# 	Iteration 17 / 2501
# 	Iteration 18 / 2501
# 	Iteration 19 / 2501
# 	Iteration 20 / 2501
# 	Iteration 21 / 2501
# 	Iteration 22 / 2501
# image: 1 eval_count: 463 success: True average_count: nan success_rate: 1.0
#
# -------------------------------
# Frame number:  1
# Starting attack
# 	Iteration 0 / 2501
# c:\Users\suman\anaconda3\envs\p38\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\suman\anaconda3\envs\p38\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# iteration: 0 loss: 4.086841583251953, l2_deviation 4.817653179168701
# 	Iteration 1 / 2501
# 	Iteration 2 / 2501
# 	Iteration 3 / 2501
# 	Iteration 4 / 2501
# 	Iteration 5 / 2501
# 	Iteration 6 / 2501
# 	Iteration 7 / 2501
# 	Iteration 8 / 2501
# 	Iteration 9 / 2501
# 	Iteration 10 / 2501
# 	Iteration 11 / 2501
# 	Iteration 12 / 2501
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31656/2974242451.py in <module>
#       9         config = json.load(reader)
#      10
# ---> 11     main(config)
#
# c:\Users\suman\Columbia\Fall 2022\Deep Learning Computer Vision\Final Project\Attack Code\commence_attack.py in main(config)
#     304         tremba_dict['image'] = image.squeeze(0).cuda()#[0].cuda()
#     305
# --> 306         adv_frames, success, stats, F.counts = TREMBA_attack(tremba_dict=tremba_dict)
#     307
#     308         adv_im = torch.clamp(image + adv_frames.unsqueeze(0), 0, 1)
#
# c:\Users\suman\Columbia\Fall 2022\Deep Learning Computer Vision\Final Project\Attack Code\commence_attack.py in TREMBA_attack(tremba_dict)
#      98     #function, encoder, decoder, image, label, config, latent=None
#      99     with torch.no_grad():
# --> 100         success, adv = EmbedBA(**tremba_dict)
#     101
#     102     F = tremba_dict["function"]
#
# c:\Users\suman\Columbia\Fall 2022\Deep Learning Computer Vision\Final Project\Attack Code\commence_attack.py in EmbedBA(function, encoder, decoder, image, label, config, latent)
#      48
#      49         perturbation = torch.clamp(decoder(latent.unsqueeze(0)).squeeze(0)*config['epsilon'], -config['epsilon'], config['epsilon'])
# ---> 50         logit, loss = function(torch.clamp(image+perturbation, 0, 1), label)
#      51         if config['target']:
#      52             success = torch.argmax(logit, dim=1) == label
#
# c:\Users\suman\anaconda3\envs\p38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\suman\Columbia\Fall 2022\Deep Learning Computer Vision\Final Project\Attack Code\TREMBA\utils.py in forward(self, images, label)
#      80 #         device = images.device
#      81         k = 0
# ---> 82         loss = torch.zeros(n, dtype=torch.float32).cuda()#, device=device)
#      83         logits = torch.zeros((n, self.nlabels), dtype=torch.float32).cuda()#, device=device)
#      84
#
# KeyboardInterrupt:
